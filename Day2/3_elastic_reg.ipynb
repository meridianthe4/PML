# %% [markdown]
# ## Hyper-parameter Tuning

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import os

# %%
os.chdir("D:/meridianthe4/PML/Datasets")

# %%
boston = pd.read_csv("Boston.csv")
X = boston.drop('medv', axis=1)
y = boston['medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
alphas = np.linspace(0.001, 15, 30)
l1 = np.linspace(0, 1, 100)
scores = []

for a in alphas:
    for r in l1:
        el = ElasticNet(alpha=a, l1_ratio=r)
        el.fit(X_train, y_train)
        y_pred = el.predict(X_test)
        scores.append([a, r, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha', 'l1_ratio', 'score'])
df_scores.sort_values('score')
# Out:
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.027e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.007e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.341e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.572e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.756e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.913e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.051e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.174e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.288e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.392e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.490e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.581e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.668e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.749e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.827e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.901e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.973e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.041e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.106e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.169e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.230e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.288e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.345e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.400e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.453e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.504e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.554e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.603e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.650e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# d:\meridianthe4\PML\main\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.695e+03, tolerance: 3.112e+00
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
#        alpha  l1_ratio      score
# 99     0.001  1.000000  21.531346
# 98     0.001  0.989899  21.533688
# 97     0.001  0.979798  21.536029
# 96     0.001  0.969697  21.538367
# 95     0.001  0.959596  21.540705
# ...      ...       ...        ...
# 2995  15.000  0.959596  38.432974
# 2996  15.000  0.969697  38.468330
# 2997  15.000  0.979798  38.504200
# 2998  15.000  0.989899  38.540592
# 2999  15.000  1.000000  38.577987
#
# [3000 rows x 3 columns]

# %% [markdown]
# ## Housing

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector

# %%
housing = pd.read_csv("Housing.csv")
X, y = housing.drop('price', axis=1), housing['price']

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform="pandas")
col_transformer = ColumnTransformer([("OHE", ohe, make_column_selector(dtype_include=object))], 
                                    remainder='passthrough', 
                                    verbose_feature_names_out=False)
col_transformer = col_transformer.set_output(transform="pandas")
X = col_transformer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
alphas = [0.001, 0.01, 0.1, 1, 1.5, 2.5, 5, 10]
scores = []

for a in alphas:
    ridge = Lasso(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha', 'score'])
df_scores.sort_values('score')
# Out:
#     alpha         score
# 7  10.000  2.726569e+08
# 6   5.000  2.726886e+08
# 5   2.500  2.727059e+08
# 4   1.500  2.727134e+08
# 3   1.000  2.727170e+08
# 2   0.100  2.727237e+08
# 1   0.010  2.727244e+08
# 0   0.001  2.727245e+08

# %%
np.arange(0.001, 15, 0.5)
# Out:
# array([1.0000e-03, 5.0100e-01, 1.0010e+00, 1.5010e+00, 2.0010e+00,
#        2.5010e+00, 3.0010e+00, 3.5010e+00, 4.0010e+00, 4.5010e+00,
#        5.0010e+00, 5.5010e+00, 6.0010e+00, 6.5010e+00, 7.0010e+00,
#        7.5010e+00, 8.0010e+00, 8.5010e+00, 9.0010e+00, 9.5010e+00,
#        1.0001e+01, 1.0501e+01, 1.1001e+01, 1.1501e+01, 1.2001e+01,
#        1.2501e+01, 1.3001e+01, 1.3501e+01, 1.4001e+01, 1.4501e+01])

# %%
np.linspace(0.001, 15, 20)
# Out:
# array([1.00000000e-03, 7.90421053e-01, 1.57984211e+00, 2.36926316e+00,
#        3.15868421e+00, 3.94810526e+00, 4.73752632e+00, 5.52694737e+00,
#        6.31636842e+00, 7.10578947e+00, 7.89521053e+00, 8.68463158e+00,
#        9.47405263e+00, 1.02634737e+01, 1.10528947e+01, 1.18423158e+01,
#        1.26317368e+01, 1.34211579e+01, 1.42105789e+01, 1.50000000e+01])

# %%
alphas = np.linspace(0.001, 15, 30)
scores = []

for a in alphas:
    ridge = Lasso(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha', 'score'])
df_scores.sort_values('score')
# Out:
#         alpha         score
# 29  15.000000  2.726289e+08
# 28  14.482793  2.726316e+08
# 27  13.965586  2.726344e+08
# 26  13.448379  2.726372e+08
# 25  12.931172  2.726400e+08
# 24  12.413966  2.726429e+08
# 23  11.896759  2.726458e+08
# 22  11.379552  2.726488e+08
# 21  10.862345  2.726518e+08
# 20  10.345138  2.726548e+08
# 19   9.827931  2.726579e+08
# 18   9.310724  2.726610e+08
# 17   8.793517  2.726642e+08
# 16   8.276310  2.726674e+08
# 15   7.759103  2.726706e+08
# 14   7.241897  2.726739e+08
# 13   6.724690  2.726773e+08
# 12   6.207483  2.726806e+08
# 11   5.690276  2.726840e+08
# 10   5.173069  2.726875e+08
# 9    4.655862  2.726910e+08
# 8    4.138655  2.726945e+08
# 7    3.621448  2.726980e+08
# 6    3.104241  2.727017e+08
# 5    2.587034  2.727053e+08
# 4    2.069828  2.727090e+08
# 3    1.552621  2.727130e+08
# 2    1.035414  2.727168e+08
# 1    0.518207  2.727206e+08
# 0    0.001000  2.727245e+08

# %% [markdown]
# ## Exp Salary

# %%
sals = pd.read_csv("Exp_Salaries.csv")
X, y = sals.drop('Salary', axis=1), sals['Salary']

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform="pandas")
col_transformer = ColumnTransformer([("OHE", ohe, make_column_selector(dtype_include=object))], 
                                    remainder='passthrough', 
                                    verbose_feature_names_out=False)
col_transformer = col_transformer.set_output(transform="pandas")
X = col_transformer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
alphas = np.linspace(0.001, 15, 30)
scores = []

for a in alphas:
    ridge = Lasso(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha', 'score'])
df_scores.sort_values('score')
# Out:
#         alpha         score
# 0    0.001000  1.338227e+07
# 1    0.518207  1.338537e+07
# 2    1.035414  1.338843e+07
# 3    1.552621  1.339171e+07
# 4    2.069828  1.339485e+07
# 5    2.587034  1.339822e+07
# 6    3.104241  1.340133e+07
# 7    3.621448  1.340477e+07
# 8    4.138655  1.340826e+07
# 9    4.655862  1.341178e+07
# 10   5.173069  1.341535e+07
# 11   5.690276  1.341895e+07
# 12   6.207483  1.342260e+07
# 13   6.724690  1.342629e+07
# 14   7.241897  1.343001e+07
# 15   7.759103  1.343378e+07
# 16   8.276310  1.343759e+07
# 17   8.793517  1.344144e+07
# 18   9.310724  1.344533e+07
# 19   9.827931  1.344926e+07
# 20  10.345138  1.345323e+07
# 21  10.862345  1.345724e+07
# 22  11.379552  1.346129e+07
# 23  11.896759  1.346538e+07
# 24  12.413966  1.346951e+07
# 25  12.931172  1.347369e+07
# 26  13.448379  1.347790e+07
# 27  13.965586  1.348215e+07
# 28  14.482793  1.348645e+07
# 29  15.000000  1.349078e+07
